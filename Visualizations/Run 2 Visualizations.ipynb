# %% [markdown]
# # Visualization for Twitter Streaming Data
#
# Run on 12/7/2019 at 11:00AM Eastern Standard Time

# %%
from google.colab import auth
auth.authenticate_user()

# %%
import pandas_gbq
import pandas as pd

# %%
# Pulling wordcount table from BigQuery
sql = """
SELECT *
FROM `cdn_dataset.hashtags`
"""
df = pandas_gbq.read_gbq(sql, project_id='reflected-space-252318')

# %%
# Print dataframe to make sure it was read into pandas properly
df.head()
# Out:
#    count        hashtags
# 0      1            #cub
# 1      1  #figureskating
# 2      1      #grandprix
# 3      1          #final
# 4      1          #black

# %%
# Sort by hashtag count in a descending manner

df = df.sort_values('count', ascending=False)

# Show the top 10 hashtags

df.head(n=10)
# Out:
#      count          hashtags
# 606     73              #lay
# 607     23   #kiisjingleball
# 608     21         #asimriaz
# 609     19          #content
# 610     16               #rt
# 611     14  #himanshikhurana
# 612     13              #hot
# 613     13         #onlyfans
# 614     13             #porn
# 619     11           #creamy

# %%
import plotly.graph_objects as go

labels = df['hashtags'].head(10).tolist()
values = df['count'].head(10).tolist()

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.3)])
fig.update_layout(
    title='Frequency Distribution of Hashtags over 20 Minute Streaming Period')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="909a1504-f3cb-45f2-b524-d07931a062f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("909a1504-f3cb-45f2-b524-d07931a062f0")) {
#                     Plotly.newPlot(
#                         '909a1504-f3cb-45f2-b524-d07931a062f0',
# ...

# %%
fig = go.Figure(go.Bar(
            x=values,
            y=labels,
            marker=dict(
                color='rgba(50, 171, 96, 0.6)',
                line=dict(
                    color='rgba(50, 171, 96, 1.0)',
                    width=1),
            ),
            orientation='h'))
fig.update_layout(
    title='Count Distribution of Hashtags over 20 Minute Streaming Period')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8bd1abd4-dd62-4060-b2b8-b7f3dc79599a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8bd1abd4-dd62-4060-b2b8-b7f3dc79599a")) {
#                     Plotly.newPlot(
#                         '8bd1abd4-dd62-4060-b2b8-b7f3dc79599a',
# ...
